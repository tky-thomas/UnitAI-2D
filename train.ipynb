# %% [markdown]
# ## Installs Prerequisites

# %%
# !pip install arcade
# !pip install torch
# !pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.4/39.4 MB 16.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 KB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 26.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 992.8/992.8 KB 4.0 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.3/965.3 KB 31.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.9/427.9 KB 37.1 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cmsetup 9.0.3446435713215707 requires boto3-stubs[essential]~=1.16.1, which is not installed.
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# ...

# %% [markdown]
# ## Simulation 1, enemies approach target

# %%
# %cd /home/hcytt1/unitai-2d
from main import main
main(graphics_mode=False,
     load_model=False,
     policy_model_save_path = 'saved_models/unit_ai_2d_policy2_1.pt',
     target_model_save_path = 'saved_models/unit_ai_2d_target2_1.pt',
     result_save_path = 'results/120523_no_death_ranged2_1.pt',
     lr=0.0001)
# Out:
# /home/hcytt1/unitai-2d
# Device: cuda
# CUDNN is enabled. CUDNN benchmark is enabled
#
# Model:
# DeepQNetwork_FullMap(
#   (cnn_model): Sequential(
#     (0): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(8, 16, kernel_size=(3, 3), stride=(3, 3), padding=(2, 2))
#     (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#   )
#   (action_selector): Sequential(
#     (0): Linear(in_features=576, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=5, bias=True)
#   )
# )
# num_params: 150509
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: False
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0
# )
# ...

# %% [markdown]
# ## Simulation 2, obstacles introduced

# %%
# %cd /home/hcytt1/unitai-2d
from main import main
main(graphics_mode=False,
     load_model=True,
     policy_model_load_path = 'saved_models/unit_ai_2d_policy2_1.pt',
     policy_model_save_path = 'saved_models/unit_ai_2d_policy2_2.pt',
     target_model_load_path = 'saved_models/unit_ai_2d_target2_1.pt',
     target_model_save_path = 'saved_models/unit_ai_2d_target2_2.pt',
     result_save_path = 'results/120523_no_death_ranged2_2.pt',
     lr=0.0001)

# %% [markdown]
# ## Simulation 3, player can damage enemies with AOE 0

# %%
# %cd /home/hcytt1/unitai-2d
from main import main
main(graphics_mode=False,
     load_model=True,
     policy_model_load_path = 'saved_models/unit_ai_2d_policy2_2.pt',
     policy_model_save_path = 'saved_models/unit_ai_2d_policy2_3.pt',
     target_model_load_path = 'saved_models/unit_ai_2d_target2_2.pt',
     target_model_save_path = 'saved_models/unit_ai_2d_target2_3.pt',
     result_save_path = 'results/120523_no_death_ranged2_3.pt',
     lr=0.00005,
     player_aoe=0)
# Out:
# /home/hcytt1/unitai-2d
# Device: cuda
# CUDNN is enabled. CUDNN benchmark is enabled
#
# Model:
# DeepQNetwork_FullMap(
#   (cnn_model): Sequential(
#     (0): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(8, 16, kernel_size=(3, 3), stride=(3, 3), padding=(2, 2))
#     (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#   )
#   (action_selector): Sequential(
#     (0): Linear(in_features=576, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=5, bias=True)
#   )
# )
# num_params: 150509
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: False
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0
# )
# ...

# %% [markdown]
# ## Simulation 4, player AOE set to 1

# %%
# %cd /home/hcytt1/unitai-2d
from main import main
main(graphics_mode=False,
     load_model=True,
     policy_model_load_path = 'saved_models/unit_ai_2d_policy2_3.pt',
     policy_model_save_path = 'saved_models/unit_ai_2d_policy2_4.pt',
     target_model_load_path = 'saved_models/unit_ai_2d_target2_3.pt',
     target_model_save_path = 'saved_models/unit_ai_2d_target2_4.pt',
     result_save_path = 'results/120523_no_death_ranged2_4.pt',
     lr=0.00005,
     player_aoe=1)
# Out:
# /home/hcytt1/unitai-2d
# Device: cuda
# CUDNN is enabled. CUDNN benchmark is enabled
#
# Model:
# DeepQNetwork_FullMap(
#   (cnn_model): Sequential(
#     (0): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(8, 16, kernel_size=(3, 3), stride=(3, 3), padding=(2, 2))
#     (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#   )
#   (action_selector): Sequential(
#     (0): Linear(in_features=576, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=5, bias=True)
#   )
# )
# num_params: 150509
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: False
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0
# )
# ...

# %% [markdown]
# ## Simulation 5, player AOE set to 2

# %%
# %cd /home/hcytt1/unitai-2d
from main import main
main(graphics_mode=False,
     load_model=True,
     policy_model_load_path = 'saved_models/unit_ai_2d_policy2_4.pt',
     policy_model_save_path = 'saved_models/unit_ai_2d_policy2_5.pt',
     target_model_load_path = 'saved_models/unit_ai_2d_target2_4.pt',
     target_model_save_path = 'saved_models/unit_ai_2d_target2_5.pt',
     result_save_path = 'results/120523_no_death_ranged2_5.pt',
     lr=0.00005,
     player_aoe=2)
# Out:
# /home/hcytt1/unitai-2d
# Device: cuda
# CUDNN is enabled. CUDNN benchmark is enabled
#
# Model:
# DeepQNetwork_FullMap(
#   (cnn_model): Sequential(
#     (0): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(8, 16, kernel_size=(3, 3), stride=(3, 3), padding=(2, 2))
#     (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#   )
#   (action_selector): Sequential(
#     (0): Linear(in_features=576, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=5, bias=True)
#   )
# )
# num_params: 150509
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: False
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0
# )
# ...

# %% [markdown]
# ## Simulation 6, player AOE set to 3

# %%
# %cd /home/hcytt1/unitai-2d
from main import main
main(graphics_mode=False,
     load_model=True,
     policy_model_load_path = 'saved_models/unit_ai_2d_policy2_5.pt',
     policy_model_save_path = 'saved_models/unit_ai_2d_policy2_6.pt',
     target_model_load_path = 'saved_models/unit_ai_2d_target2_5.pt',
     target_model_save_path = 'saved_models/unit_ai_2d_target2_6.pt',
     result_save_path = 'results/120523_no_death_ranged2_6.pt',
     lr=0.00005,
     player_aoe=3)
# Out:
# /home/hcytt1/unitai-2d
# Device: cuda
# CUDNN is enabled. CUDNN benchmark is enabled
#
# Model:
# DeepQNetwork_FullMap(
#   (cnn_model): Sequential(
#     (0): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(8, 16, kernel_size=(3, 3), stride=(3, 3), padding=(2, 2))
#     (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#   )
#   (action_selector): Sequential(
#     (0): Linear(in_features=576, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=5, bias=True)
#   )
# )
# num_params: 150509
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: False
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0
# )
# ...
